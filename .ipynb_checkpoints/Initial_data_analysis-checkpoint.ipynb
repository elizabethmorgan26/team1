# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.stats import linregress
import hvplot.pandas
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="cf27dfd2-a4dc-4235-a0d0-08ab92b8ed06" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"04a3cd91-ece1-4a25-9d44-d375942e2094":{"version":"3.3.2","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1002"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1003","attributes":{"plot_id":"p1002","comm_id":"7ebaf7a1e4c74ec9a6f9cc943b518195","client_comm_id":"bdef82d819694073965039eee62ea5db"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"Any","default":"none"},{"name":"value","kind":"Any","default":null}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]}]}};
#   var render_items = [{"docid":"04a3cd91-ece1-4a25-9d44-d375942e2094","roots":{"p1002":"cf27dfd2-a4dc-4235-a0d0-08ab92b8ed06"},"root_ids":["p1002"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
storms_2022 = pd.read_csv("resources/stormevents_2022.csv")

storms_2022
# Out:
#        BEGIN_YEARMONTH  BEGIN_DAY  BEGIN_TIME  END_YEARMONTH  END_DAY  \
# 0               202202         20        2118         202202       20
# 1               202202         21         800         202202       22
# 2               202202         22         200         202202       22
# 3               202202         18        1609         202202       18
# 4               202202          2           0         202202        3
# ...                ...        ...         ...            ...      ...
# 69665           202206         16        1000         202206       16
# 69666           202206         16        1000         202206       16
# 69667           202207         20        1815         202207       20
# 69668           202207         28        1300         202207       28
# 69669           202207         28        1330         202207       28
#
#        END_TIME  EPISODE_ID  EVENT_ID           STATE  STATE_FIPS  ...  \
# 0          2218      165464    999902          NEVADA          32  ...
# 1          1000      165465    999903          NEVADA          32  ...
# 2           900      165465    999904          NEVADA          32  ...
# 3          1609      165611   1001181  ATLANTIC SOUTH          87  ...
# 4             0      165668   1001527  AMERICAN SAMOA          97  ...
# ...         ...         ...       ...             ...         ...  ...
# 69665      2000      171350   1040244         ARIZONA           4  ...
# 69666      2000      171350   1040248         ARIZONA           4  ...
# 69667      1815      172682   1049136         ARIZONA           4  ...
# 69668      1430      172688   1050042         ARIZONA           4  ...
# 69669      1500      172688   1050044         ARIZONA           4  ...
#
#        END_RANGE END_AZIMUTH  END_LOCATION BEGIN_LAT  BEGIN_LON  END_LAT  \
# 0            NaN         NaN           NaN       NaN        NaN      NaN
# 1            NaN         NaN           NaN       NaN        NaN      NaN
# 2            NaN         NaN           NaN       NaN        NaN      NaN
# 3            7.0          SE   PONTE VEDRA   30.0500   -81.1700  30.0500
# 4            5.0         NNW       VAITOGI  -14.3330  -170.7157 -14.3393
# ...          ...         ...           ...       ...        ...      ...
# 69665        NaN         NaN           NaN       NaN        NaN      NaN
# 69666        NaN         NaN           NaN       NaN        NaN      NaN
# 69667        4.0         NNE        PEARCE   31.9489  -109.8038  31.9489
# 69668       10.0           N  COPPER CREEK   32.8976  -110.4206  32.8909
# 69669        4.0          SE    SAN MANUEL   32.5160  -110.7084  32.5550
#
#         END_LON                                  EPISODE_NARRATIVE  \
# 0           NaN  Strong winds increased ahead of an approaching...
# 1           NaN  A low centered over northern and central Nevad...
# 2           NaN  A low centered over northern and central Nevad...
# 3      -81.1700  Pre-frontal showers and thunderstorms moved so...
# 4     -170.7268  A surface trough over the Islands held  the po...
# ...         ...                                                ...
# 69665       NaN  Very hot temperatures 7 to 10 degrees above no...
# 69666       NaN  Very hot temperatures 7 to 10 degrees above no...
# 69667 -109.8038  During the afternoon and evening, scattered th...
# 69668 -110.4452  Scattered slow moving thunderstorms developed ...
# 69669 -110.5904  Scattered slow moving thunderstorms developed ...
#
#                                          EVENT_NARRATIVE DATA_SOURCE
# 0      Station (UP994) 3.1 SE West Wendover, Elevatio...         CSV
# 1      Thirteen inches fell at station (BCSN2) Big Cr...         CSV
# 2      Fifteen inches fell at station (TJMN2) Toe Jam...         CSV
# 3      A brief waterspout was observed offshore of So...         CSV
# 4      Over a 24-hour period, WSO Pago Pago recorded ...         CSV
# ...                                                  ...         ...
# 69665  Very hot high temperatures occurred across San...         CSV
# 69666  Very hot high temperatures occurred across Gra...         CSV
# 69667  One inch diameter hail combined with wind gust...         CSV
# 69668  Heavy rain of 2-3 in 90 minutes in Aravaipa Ca...         CSV
# 69669  Heavy rain of 1-2 in less than 2 hours over th...         CSV
#
# [69670 rows x 51 columns]

# %%
storms_2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69670 entries, 0 to 69669
# Data columns (total 51 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   BEGIN_YEARMONTH     69670 non-null  int64
#  1   BEGIN_DAY           69670 non-null  int64
#  2   BEGIN_TIME          69670 non-null  int64
#  3   END_YEARMONTH       69670 non-null  int64
#  4   END_DAY             69670 non-null  int64
#  5   END_TIME            69670 non-null  int64
#  6   EPISODE_ID          69670 non-null  int64
#  7   EVENT_ID            69670 non-null  int64
#  8   STATE               69670 non-null  object
#  9   STATE_FIPS          69670 non-null  int64
#  10  YEAR                69670 non-null  int64
#  11  MONTH_NAME          69670 non-null  object
#  12  EVENT_TYPE          69670 non-null  object
#  13  CZ_TYPE             69670 non-null  object
#  14  CZ_FIPS             69670 non-null  int64
#  15  CZ_NAME             69670 non-null  object
#  16  WFO                 69670 non-null  object
#  17  BEGIN_DATE_TIME     69670 non-null  object
#  18  CZ_TIMEZONE         69670 non-null  object
#  19  END_DATE_TIME       69670 non-null  object
#  20  INJURIES_DIRECT     69670 non-null  int64
#  21  INJURIES_INDIRECT   69670 non-null  int64
#  22  DEATHS_DIRECT       69670 non-null  int64
#  23  DEATHS_INDIRECT     69670 non-null  int64
#  24  DAMAGE_PROPERTY     53279 non-null  object
#  25  DAMAGE_CROPS        53862 non-null  object
#  26  SOURCE              69670 non-null  object
#  27  MAGNITUDE           33738 non-null  float64
#  28  MAGNITUDE_TYPE      26529 non-null  object
#  29  FLOOD_CAUSE         5237 non-null   object
#  30  CATEGORY            23 non-null     float64
#  31  TOR_F_SCALE         1379 non-null   object
#  32  TOR_LENGTH          1379 non-null   float64
#  33  TOR_WIDTH           1379 non-null   float64
#  34  TOR_OTHER_WFO       215 non-null    object
#  35  TOR_OTHER_CZ_STATE  215 non-null    object
#  36  TOR_OTHER_CZ_FIPS   215 non-null    float64
#  37  TOR_OTHER_CZ_NAME   215 non-null    object
#  38  BEGIN_RANGE         35846 non-null  float64
#  39  BEGIN_AZIMUTH       35846 non-null  object
#  40  BEGIN_LOCATION      35846 non-null  object
#  41  END_RANGE           35846 non-null  float64
#  42  END_AZIMUTH         35846 non-null  object
#  43  END_LOCATION        35846 non-null  object
#  44  BEGIN_LAT           35846 non-null  float64
#  45  BEGIN_LON           35846 non-null  float64
#  46  END_LAT             35846 non-null  float64
#  47  END_LON             35846 non-null  float64
#  48  EPISODE_NARRATIVE   69670 non-null  object
#  49  EVENT_NARRATIVE     56045 non-null  object
#  50  DATA_SOURCE         69670 non-null  object
# dtypes: float64(11), int64(15), object(25)
# memory usage: 27.1+ MB

# %%
storms_2022["EVENT_TYPE"].value_counts()
# Out:
# EVENT_TYPE
# Thunderstorm Wind             17595
# Hail                           7180
# Drought                        6873
# High Wind                      5179
# Winter Weather                 4762
# Winter Storm                   3644
# Flash Flood                    3097
# Marine Thunderstorm Wind       2579
# Heavy Snow                     2318
# Flood                          1961
# Heat                           1871
# Extreme Cold/Wind Chill        1855
# Tornado                        1379
# Excessive Heat                 1280
# Strong Wind                    1066
# Heavy Rain                     1047
# Cold/Wind Chill                 992
# Blizzard                        854
# Dense Fog                       571
# Frost/Freeze                    423
# Wildfire                        421
# High Surf                       341
# Ice Storm                       261
# Lightning                       261
# Dust Storm                      238
# Tropical Storm                  230
# Waterspout                      215
# Coastal Flood                   205
# Funnel Cloud                    204
# Debris Flow                     179
# Marine High Wind                105
# Lake-Effect Snow                 88
# Rip Current                      82
# Marine Tropical Storm            45
# Astronomical Low Tide            43
# Sleet                            42
# Storm Surge/Tide                 32
# Avalanche                        29
# Marine Hail                      29
# Hurricane                        23
# Tropical Depression              22
# Dust Devil                       10
# Tsunami                           9
# Marine Strong Wind                5
# Marine Dense Fog                  4
# Lakeshore Flood                   4
# Marine Hurricane/Typhoon          4
# Freezing Fog                      3
# Marine Tropical Depression        3
# Dense Smoke                       3
# Seiche                            2
# Sneakerwave                       1
# Volcanic Ashfall                  1
# Name: count, dtype: int64

# %%
map_plot_1 = storms_2022.hvplot.points(
    "BEGIN_LON",
    "BEGIN_LAT" ,
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 450,
    legend = False, 
    hover_cols = "EPISODE_ID")

map_plot_1
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [BEGIN_LON,BEGIN_LAT]   (EPISODE_ID)

# %%
tornado = storms_2022.loc[(storms_2022["EVENT_TYPE"] == "Tornado") & (storms_2022["INJURIES_DIRECT"] != 0)]
len(tornado)
# Out:
# 76

# %%
drought = storms_2022.loc[(storms_2022["EVENT_TYPE"] == "Drought")]
drought["STATE"].value_counts()
# Out:
# STATE
# TEXAS             1896
# OKLAHOMA           895
# CALIFORNIA         606
# NEW MEXICO         521
# NEBRASKA           508
# KANSAS             354
# MISSOURI           275
# HAWAII             240
# SOUTH DAKOTA       227
# IOWA               203
# MONTANA            158
# TENNESSEE          110
# ARKANSAS           107
# LOUISIANA           97
# KENTUCKY            95
# NORTH DAKOTA        88
# ILLINOIS            75
# FLORIDA             68
# MINNESOTA           53
# UTAH                52
# COLORADO            50
# MISSISSIPPI         31
# NORTH CAROLINA      26
# MAINE               20
# PUERTO RICO         16
# ARIZONA             14
# WISCONSIN           12
# GUAM                12
# NEW HAMPSHIRE       12
# GEORGIA             10
# NEW YORK            10
# VIRGIN ISLANDS       7
# CONNECTICUT          6
# ALABAMA              6
# MASSACHUSETTS        6
# VERMONT              4
# VIRGINIA             3
# Name: count, dtype: int64

# %%
tornado["INJURIES_DIRECT"].sum()
# Out:
# 314

# %%
#tornado with injuries map

map_plot_2 = tornado.hvplot.points(
    "BEGIN_LON",
    "BEGIN_LAT",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 450,
    legend = False, 
    hover_cols = ["EPISODE_ID","INJURIES_DIRECT","DAMAGE_PROPERTY"])

map_plot_2
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [BEGIN_LON,BEGIN_LAT]   (EPISODE_ID,INJURIES_DIRECT,DAMAGE_PROPERTY)

# %%
storms_2022.columns
# Out:
# Index(['BEGIN_YEARMONTH', 'BEGIN_DAY', 'BEGIN_TIME', 'END_YEARMONTH',
#        'END_DAY', 'END_TIME', 'EPISODE_ID', 'EVENT_ID', 'STATE', 'STATE_FIPS',
#        'YEAR', 'MONTH_NAME', 'EVENT_TYPE', 'CZ_TYPE', 'CZ_FIPS', 'CZ_NAME',
#        'WFO', 'BEGIN_DATE_TIME', 'CZ_TIMEZONE', 'END_DATE_TIME',
#        'INJURIES_DIRECT', 'INJURIES_INDIRECT', 'DEATHS_DIRECT',
#        'DEATHS_INDIRECT', 'DAMAGE_PROPERTY', 'DAMAGE_CROPS', 'SOURCE',
#        'MAGNITUDE', 'MAGNITUDE_TYPE', 'FLOOD_CAUSE', 'CATEGORY', 'TOR_F_SCALE',
#        'TOR_LENGTH', 'TOR_WIDTH', 'TOR_OTHER_WFO', 'TOR_OTHER_CZ_STATE',
#        'TOR_OTHER_CZ_FIPS', 'TOR_OTHER_CZ_NAME', 'BEGIN_RANGE',
#        'BEGIN_AZIMUTH', 'BEGIN_LOCATION', 'END_RANGE', 'END_AZIMUTH',
#        'END_LOCATION', 'BEGIN_LAT', 'BEGIN_LON', 'END_LAT', 'END_LON',
#        'EPISODE_NARRATIVE', 'EVENT_NARRATIVE', 'DATA_SOURCE'],
#       dtype='object')

# %%
cols = ['EPISODE_ID','EVENT_ID','BEGIN_YEARMONTH','BEGIN_DAY','STATE', 'EVENT_TYPE', 'INJURIES_DIRECT', 'INJURIES_INDIRECT', 'DEATHS_DIRECT',
       'DEATHS_INDIRECT', 'DAMAGE_PROPERTY', 'DAMAGE_CROPS', 'SOURCE']

clean = storms_2022[cols]

clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69670 entries, 0 to 69669
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   EPISODE_ID         69670 non-null  int64
#  1   EVENT_ID           69670 non-null  int64
#  2   BEGIN_YEARMONTH    69670 non-null  int64
#  3   BEGIN_DAY          69670 non-null  int64
#  4   STATE              69670 non-null  object
#  5   EVENT_TYPE         69670 non-null  object
#  6   INJURIES_DIRECT    69670 non-null  int64
#  7   INJURIES_INDIRECT  69670 non-null  int64
#  8   DEATHS_DIRECT      69670 non-null  int64
#  9   DEATHS_INDIRECT    69670 non-null  int64
#  10  DAMAGE_PROPERTY    53279 non-null  object
#  11  DAMAGE_CROPS       53862 non-null  object
#  12  SOURCE             69670 non-null  object
# dtypes: int64(8), object(5)
# memory usage: 6.9+ MB

# %%
clean.iloc[27,:]
# Out:
# EPISODE_ID                   166087
# EVENT_ID                    1004178
# BEGIN_YEARMONTH              202201
# BEGIN_DAY                        16
# STATE                          OHIO
# EVENT_TYPE           Winter Weather
# INJURIES_DIRECT                   0
# INJURIES_INDIRECT                 0
# DEATHS_DIRECT                     0
# DEATHS_INDIRECT                   0
# DAMAGE_PROPERTY                 NaN
# DAMAGE_CROPS                    NaN
# SOURCE                     CoCoRaHS
# Name: 27, dtype: object

# %%
len(clean[clean["DAMAGE_CROPS"]== "0.00K"])
# Out:
# 52924

# %%
len(clean[clean["DAMAGE_CROPS"].isna()])
# Out:
# 15808

# %%
clean.loc[:,"DAMAGE_PROPERTY"]=clean["DAMAGE_PROPERTY"].fillna("0.00K")
clean.loc[:,"DAMAGE_CROPS"]=clean["DAMAGE_CROPS"].fillna("0.00K")
clean.iloc[27,:]
# Out:
# EPISODE_ID                   166087
# EVENT_ID                    1004178
# BEGIN_YEARMONTH              202201
# BEGIN_DAY                        16
# STATE                          OHIO
# EVENT_TYPE           Winter Weather
# INJURIES_DIRECT                   0
# INJURIES_INDIRECT                 0
# DEATHS_DIRECT                     0
# DEATHS_INDIRECT                   0
# DAMAGE_PROPERTY               0.00K
# DAMAGE_CROPS                  0.00K
# SOURCE                     CoCoRaHS
# Name: 27, dtype: object

# %%
len(clean[clean["DAMAGE_CROPS"].isna()])
# Out:
# 0

# %%
len(clean[clean["DAMAGE_CROPS"] == "0.00K"])
# Out:
# 68732

# %%
clean_no_zeros = clean.loc[(clean["INJURIES_DIRECT"] != 0)|
                            (clean["INJURIES_INDIRECT"]!= 0)|
                            (clean["DEATHS_DIRECT"]!= 0)|
                            (clean["DEATHS_INDIRECT"]!= 0)|
                            (clean["DAMAGE_PROPERTY"]!= "0.00K")|
                            (clean["DAMAGE_CROPS"]!= "0.00K")]
clean_no_zeros
# Out:
#        EPISODE_ID  EVENT_ID  BEGIN_YEARMONTH  BEGIN_DAY           STATE  \
# 4          165668   1001527           202202          2  AMERICAN SAMOA
# 12         165593   1001094           202202         25         FLORIDA
# 36         168040   1034259           202203         30       LOUISIANA
# 37         168040   1034260           202203         30       LOUISIANA
# 38         168039   1035604           202203         30     MISSISSIPPI
# ...           ...       ...              ...        ...             ...
# 69659      171292   1131613           202206         12         ARIZONA
# 69660      174064   1055721           202208          1           TEXAS
# 69662      175951   1071358           202212         14       LOUISIANA
# 69664      171350   1040241           202206         16         ARIZONA
# 69669      172688   1050044           202207         28         ARIZONA
#
#            EVENT_TYPE  INJURIES_DIRECT  INJURIES_INDIRECT  DEATHS_DIRECT  \
# 4          Heavy Rain                0                  0              0
# 12          Dense Fog                0                 30              0
# 36            Tornado                0                  0              0
# 37            Tornado                0                  0              0
# 38            Tornado                0                  0              0
# ...               ...              ...                ...            ...
# 69659            Heat                0                  0              1
# 69660         Drought                0                  0              0
# 69662         Tornado                8                  0              1
# 69664  Excessive Heat                0                  0              1
# 69669     Flash Flood                0                  0              0
#
#        DEATHS_INDIRECT DAMAGE_PROPERTY DAMAGE_CROPS                     SOURCE
# 4                    0          50.00K        0.00K  Official NWS Observations
# 12                   0           0.00K        0.00K          Emergency Manager
# 36                   0          50.00K        0.00K           NWS Storm Survey
# 37                   0          85.00K        0.00K           NWS Storm Survey
# 38                   0          35.00K        0.00K           NWS Storm Survey
# ...                ...             ...          ...                        ...
# 69659                0           0.00K        0.00K            County Official
# 69660                0           0.00K        2.87M            Drought Monitor
# 69662                0         250.00K        0.00K           NWS Storm Survey
# 69664                0           0.00K        0.00K            County Official
# 69669                0          25.00K        0.00K          Emergency Manager
#
# [12573 rows x 13 columns]

# %%
clean_no_zeros["EVENT_TYPE"].value_counts()
# Out:
# EVENT_TYPE
# Thunderstorm Wind           7599
# Flash Flood                 1163
# Tornado                      644
# Strong Wind                  602
# Flood                        430
# Hail                         402
# High Wind                    267
# Lightning                    259
# Drought                      162
# Winter Storm                 123
# Winter Weather               116
# Wildfire                     110
# Tropical Storm                90
# Debris Flow                   89
# Heat                          86
# Rip Current                   69
# Cold/Wind Chill               43
# Excessive Heat                40
# Heavy Rain                    32
# Heavy Snow                    32
# Extreme Cold/Wind Chill       29
# Coastal Flood                 28
# Blizzard                      26
# Ice Storm                     24
# Dense Fog                     20
# High Surf                     14
# Avalanche                     12
# Hurricane                     11
# Lake-Effect Snow              11
# Dust Storm                    11
# Marine Strong Wind             5
# Dust Devil                     4
# Storm Surge/Tide               4
# Waterspout                     2
# Marine Thunderstorm Wind       2
# Tropical Depression            2
# Tsunami                        2
# Marine Tropical Storm          2
# Freezing Fog                   1
# Marine Dense Fog               1
# Astronomical Low Tide          1
# Sneakerwave                    1
# Sleet                          1
# Lakeshore Flood                1
# Name: count, dtype: int64

# %%
clean.groupby(["STATE","EVENT_TYPE"])["EVENT_TYPE"].count()
# Out:
# STATE    EVENT_TYPE
# ALABAMA  Cold/Wind Chill             23
#          Drought                      6
#          Excessive Heat               8
#          Extreme Cold/Wind Chill     10
#          Flash Flood                115
#                                    ...
# WYOMING  Thunderstorm Wind           67
#          Tornado                      2
#          Wildfire                     1
#          Winter Storm               121
#          Winter Weather              62
# Name: EVENT_TYPE, Length: 1069, dtype: int64

# %%
storms_2022.loc[storms_2022["BEGIN_DAY"] != storms_2022["END_DAY"],:]
# Out:
#        BEGIN_YEARMONTH  BEGIN_DAY  BEGIN_TIME  END_YEARMONTH  END_DAY  \
# 1               202202         21         800         202202       22
# 4               202202          2           0         202202        3
# 8               202202         13         200         202202       14
# 9               202202         13         400         202202       14
# 10              202202         13         400         202202       14
# ...                ...        ...         ...            ...      ...
# 69635           202208          1           0         202208       16
# 69637           202206         12        1030         202206       22
# 69639           202206          9        1000         202206       12
# 69648           202206          1           0         202206       30
# 69660           202208          1           0         202208       25
#
#        END_TIME  EPISODE_ID  EVENT_ID           STATE  STATE_FIPS  ...  \
# 1          1000      165465    999903          NEVADA          32  ...
# 4             0      165668   1001527  AMERICAN SAMOA          97  ...
# 8           600      165868   1002855   MASSACHUSETTS          25  ...
# 9           800      165868   1002857   MASSACHUSETTS          25  ...
# 10          800      165868   1002858   MASSACHUSETTS          25  ...
# ...         ...         ...       ...             ...         ...  ...
# 69635         0      174064   1055743           TEXAS          48  ...
# 69637       700      171144   1039309         ARIZONA           4  ...
# 69639      1900      171292   1040205         ARIZONA           4  ...
# 69648      2359      171139   1038954         ARIZONA           4  ...
# 69660         0      174064   1055721           TEXAS          48  ...
#
#        END_RANGE END_AZIMUTH END_LOCATION BEGIN_LAT  BEGIN_LON  END_LAT  \
# 1            NaN         NaN          NaN       NaN        NaN      NaN
# 4            5.0         NNW      VAITOGI   -14.333  -170.7157 -14.3393
# 8            NaN         NaN          NaN       NaN        NaN      NaN
# 9            NaN         NaN          NaN       NaN        NaN      NaN
# 10           NaN         NaN          NaN       NaN        NaN      NaN
# ...          ...         ...          ...       ...        ...      ...
# 69635        NaN         NaN          NaN       NaN        NaN      NaN
# 69637        NaN         NaN          NaN       NaN        NaN      NaN
# 69639        NaN         NaN          NaN       NaN        NaN      NaN
# 69648        NaN         NaN          NaN       NaN        NaN      NaN
# 69660        NaN         NaN          NaN       NaN        NaN      NaN
#
#         END_LON                                  EPISODE_NARRATIVE  \
# 1           NaN  A low centered over northern and central Nevad...
# 4     -170.7268  A surface trough over the Islands held  the po...
# 8           NaN  A low pressure system tracked offshore of Sout...
# 9           NaN  A low pressure system tracked offshore of Sout...
# 10          NaN  A low pressure system tracked offshore of Sout...
# ...         ...                                                ...
# 69635       NaN  Severe to extreme drought conditions over all ...
# 69637       NaN  The Tonto Canyon Fire resulted from the combin...
# 69639       NaN  Very hot temperatures 7 to 10 degrees above no...
# 69648       NaN  Extreme drought (D3) category continued across...
# 69660       NaN  Severe to extreme drought conditions over all ...
#
#                                          EVENT_NARRATIVE DATA_SOURCE
# 1      Thirteen inches fell at station (BCSN2) Big Cr...         CSV
# 4      Over a 24-hour period, WSO Pago Pago recorded ...         CSV
# 8      Snowfall was generally 5 to 9 inches. The high...         CSV
# 9      Snowfall was generally 6 to 8 inches. The high...         CSV
# 10     Snowfall generally ranged from 7 to 9 inches. ...         CSV
# ...                                                  ...         ...
# 69635  Extreme drought over the western part of the c...         CSV
# 69637  The Tonto Canyon Fire resulted from the combin...         CSV
# 69639  Very hot high temperatures of 104 to 110 degre...         CSV
# 69648  Extreme drought (D3) category continued across...         CSV
# 69660  Extreme drought over the county improved to ab...         CSV
#
# [20923 rows x 51 columns]

# %%
storms_2022.loc[ (storms_2022["END_DAY"]- storms_2022["BEGIN_DAY"]) > 10,:]
# Out:
#        BEGIN_YEARMONTH  BEGIN_DAY  BEGIN_TIME  END_YEARMONTH  END_DAY  \
# 57              202212          1           0         202212       31
# 58              202212          1           0         202212       31
# 66              202212          1           0         202212       31
# 82              202205          1           0         202205       15
# 83              202205          1           0         202205       15
# ...                ...        ...         ...            ...      ...
# 69633           202208          1           0         202208       16
# 69634           202208          1           0         202208       16
# 69635           202208          1           0         202208       16
# 69648           202206          1           0         202206       30
# 69660           202208          1           0         202208       25
#
#        END_TIME  EPISODE_ID  EVENT_ID       STATE  STATE_FIPS  ...  END_RANGE  \
# 57         2359      175684   1066892  CALIFORNIA           6  ...        NaN
# 58         2359      175684   1066896  CALIFORNIA           6  ...        NaN
# 66         2359      175684   1066898  CALIFORNIA           6  ...        NaN
# 82         2359      170371   1032987    OKLAHOMA          40  ...        NaN
# 83         2359      170371   1032988    OKLAHOMA          40  ...        NaN
# ...         ...         ...       ...         ...         ...  ...        ...
# 69633         0      174064   1055741       TEXAS          48  ...        NaN
# 69634         0      174064   1055742       TEXAS          48  ...        NaN
# 69635         0      174064   1055743       TEXAS          48  ...        NaN
# 69648      2359      171139   1038954     ARIZONA           4  ...        NaN
# 69660         0      174064   1055721       TEXAS          48  ...        NaN
#
#       END_AZIMUTH END_LOCATION BEGIN_LAT  BEGIN_LON END_LAT END_LON  \
# 57            NaN          NaN       NaN        NaN     NaN     NaN
# 58            NaN          NaN       NaN        NaN     NaN     NaN
# 66            NaN          NaN       NaN        NaN     NaN     NaN
# 82            NaN          NaN       NaN        NaN     NaN     NaN
# 83            NaN          NaN       NaN        NaN     NaN     NaN
# ...           ...          ...       ...        ...     ...     ...
# 69633         NaN          NaN       NaN        NaN     NaN     NaN
# 69634         NaN          NaN       NaN        NaN     NaN     NaN
# 69635         NaN          NaN       NaN        NaN     NaN     NaN
# 69648         NaN          NaN       NaN        NaN     NaN     NaN
# 69660         NaN          NaN       NaN        NaN     NaN     NaN
#
#                                        EPISODE_NARRATIVE  \
# 57     Interior Northern California is still experien...
# 58     Interior Northern California is still experien...
# 66     Interior Northern California is still experien...
# 82     Severe drought persisted across much of wester...
# 83     Severe drought persisted across much of wester...
# ...                                                  ...
# 69633  Severe to extreme drought conditions over all ...
# 69634  Severe to extreme drought conditions over all ...
# 69635  Severe to extreme drought conditions over all ...
# 69648  Extreme drought (D3) category continued across...
# 69660  Severe to extreme drought conditions over all ...
#
#                                          EVENT_NARRATIVE DATA_SOURCE
# 57     For the month of December, the U.S. Drought Mo...         CSV
# 58     For the month of December, the U.S. Drought Mo...         CSV
# 66     For the month of December, the U.S. Drought Mo...         CSV
# 82                                                   NaN         CSV
# 83                                                   NaN         CSV
# ...                                                  ...         ...
# 69633  Severe drought improved to abnormally dry by t...         CSV
# 69634  Severe drought improved to abnormally dry by t...         CSV
# 69635  Extreme drought over the western part of the c...         CSV
# 69648  Extreme drought (D3) category continued across...         CSV
# 69660  Extreme drought over the county improved to ab...         CSV
#
# [6761 rows x 51 columns]

# %%
cali_flor = storms_2022.loc[(storms_2022["STATE"] == "CALIFORNIA")| (storms_2022["STATE"] == "FLORIDA")]
cali_flor.head()
# Out:
#     BEGIN_YEARMONTH  BEGIN_DAY  BEGIN_TIME  END_YEARMONTH  END_DAY  END_TIME  \
# 12           202202         25         500         202202       25      1000
# 22           202212          1        1120         202212        1      1120
# 23           202212         27         310         202212       27       310
# 25           202209         18        1800         202209       18      1800
# 57           202212          1           0         202212       31      2359
#
#     EPISODE_ID  EVENT_ID       STATE  STATE_FIPS  ...  END_RANGE END_AZIMUTH  \
# 12      165593   1001094     FLORIDA          12  ...        NaN         NaN
# 22      176256   1070548  CALIFORNIA           6  ...        NaN         NaN
# 23      176263   1071368  CALIFORNIA           6  ...        NaN         NaN
# 25      173301   1052336     FLORIDA          12  ...        2.0         NNE
# 57      175684   1066892  CALIFORNIA           6  ...        NaN         NaN
#
#    END_LOCATION BEGIN_LAT  BEGIN_LON  END_LAT  END_LON  \
# 12          NaN       NaN        NaN      NaN      NaN
# 22          NaN       NaN        NaN      NaN      NaN
# 23          NaN       NaN        NaN      NaN      NaN
# 25      KENWOOD   29.5415   -81.8741  29.5562 -81.8721
# 57          NaN       NaN        NaN      NaN      NaN
#
#                                     EPISODE_NARRATIVE  \
# 12  A multi-vehicle crash occurred in dense fog in...
# 22  A strong winter storm generated a series of fo...
# 23  During the final week of December, a very acti...
# 25  A persistent upper-level trough lingered over ...
# 57  Interior Northern California is still experien...
#
#                                       EVENT_NARRATIVE DATA_SOURCE
# 12  A multi-vehicle crash occurred in dense fog in...         CSV
# 22  Mesonet station (HVRTM-Blue Streak), located 1...         CSV
# 23  Mesonet site (HVRTM) Blue Streak Weather stati...         CSV
# 25        Street flooding was reported in Hog Valley.         CSV
# 57  For the month of December, the U.S. Drought Mo...         CSV
#
# [5 rows x 51 columns]

# %%
cali_flor.groupby(["STATE", "EVENT_TYPE"])["EPISODE_ID"].count()
# Out:
# STATE       EVENT_TYPE
# CALIFORNIA  Avalanche                    1
#             Coastal Flood                3
#             Cold/Wind Chill              7
#             Debris Flow                 51
#             Dense Fog                  155
#             Dense Smoke                  1
#             Drought                    606
#             Dust Storm                  28
#             Excessive Heat             117
#             Extreme Cold/Wind Chill      2
#             Flash Flood                172
#             Flood                      164
#             Frost/Freeze               118
#             Funnel Cloud                 3
#             Hail                         9
#             Heat                       229
#             Heavy Rain                 125
#             Heavy Snow                 155
#             High Surf                    5
#             High Wind                  473
#             Lightning                    6
#             Rip Current                  2
#             Sneakerwave                  1
#             Storm Surge/Tide             2
#             Strong Wind                129
#             Thunderstorm Wind           43
#             Tornado                      4
#             Tsunami                      5
#             Wildfire                    42
#             Winter Storm                50
#             Winter Weather              81
# FLORIDA     Coastal Flood                2
#             Cold/Wind Chill             26
#             Dense Fog                    3
#             Drought                     68
#             Dust Devil                   1
#             Excessive Heat               9
#             Flash Flood                 69
#             Flood                      103
#             Frost/Freeze                 8
#             Funnel Cloud                28
#             Hail                       109
#             Heat                         1
#             Heavy Rain                  69
#             High Surf                    2
#             High Wind                    1
#             Hurricane                   23
#             Lightning                   46
#             Rip Current                 21
#             Storm Surge/Tide            19
#             Strong Wind                  5
#             Thunderstorm Wind          434
#             Tornado                     71
#             Tropical Depression         15
#             Tropical Storm             107
#             Wildfire                     1
#             Winter Weather               1
# Name: EPISODE_ID, dtype: int64

# %%
len(storms_2022["EPISODE_ID"].unique())
# Out:
# 10445

# %%
len(storms_2022["EVENT_ID"].unique())
# Out:
# 69670

# %%
storms_2022.groupby("EPISODE_ID")["EVENT_ID"].count()
# Out:
# EPISODE_ID
# 164146    12
# 164147     1
# 164156     2
# 164158    11
# 164159     4
#           ..
# 186345    34
# 186366     6
# 186451     6
# 186474     6
# 186475    10
# Name: EVENT_ID, Length: 10445, dtype: int64

# %%
storms_2022.loc[storms_2022["EVENT_TYPE"] == "Tornado"].iloc[0]
# Out:
# BEGIN_YEARMONTH                                                  202203
# BEGIN_DAY                                                            30
# BEGIN_TIME                                                         1303
# END_YEARMONTH                                                    202203
# END_DAY                                                              30
# END_TIME                                                           1306
# EPISODE_ID                                                       168040
# EVENT_ID                                                        1034259
# STATE                                                         LOUISIANA
# STATE_FIPS                                                           22
# YEAR                                                               2022
# MONTH_NAME                                                        March
# EVENT_TYPE                                                      Tornado
# CZ_TYPE                                                               C
# CZ_FIPS                                                              83
# CZ_NAME                                                        RICHLAND
# WFO                                                                 JAN
# BEGIN_DATE_TIME                                      30-MAR-22 13:03:00
# CZ_TIMEZONE                                                       CST-6
# END_DATE_TIME                                        30-MAR-22 13:06:00
# INJURIES_DIRECT                                                       0
# INJURIES_INDIRECT                                                     0
# DEATHS_DIRECT                                                         0
# DEATHS_INDIRECT                                                       0
# DAMAGE_PROPERTY                                                  50.00K
# DAMAGE_CROPS                                                      0.00K
# SOURCE                                                 NWS Storm Survey
# MAGNITUDE                                                           NaN
# MAGNITUDE_TYPE                                                      NaN
# FLOOD_CAUSE                                                         NaN
# CATEGORY                                                            NaN
# TOR_F_SCALE                                                         EF0
# TOR_LENGTH                                                         1.78
# TOR_WIDTH                                                          25.0
# TOR_OTHER_WFO                                                       NaN
# TOR_OTHER_CZ_STATE                                                  NaN
# TOR_OTHER_CZ_FIPS                                                   NaN
# TOR_OTHER_CZ_NAME                                                   NaN
# BEGIN_RANGE                                                         3.0
# BEGIN_AZIMUTH                                                         E
# BEGIN_LOCATION                                                   DEHLCO
# END_RANGE                                                           4.0
# END_AZIMUTH                                                         ENE
# END_LOCATION                                                     DEHLCO
# BEGIN_LAT                                                       32.3733
# BEGIN_LON                                                      -91.7256
# END_LAT                                                         32.3934
# END_LON                                                        -91.7065
# EPISODE_NARRATIVE     A strong weather system interacted with an uns...
# EVENT_NARRATIVE       This weak and brief tornado started in an open...
# DATA_SOURCE                                                         CSV
# Name: 36, dtype: object
